# %%
# Install environment and agent
# Environment
import gym
import highway_env

# Agent
from stable_baselines3 import DQN

# Visualization utils
# %load_ext tensorboard
import sys
from tqdm.notebook import trange
#!pip install tensorboardx gym pyvirtualdisplay
#!apt-get install -y xvfb python-opengl ffmpeg
#!git clone https://github.com/eleurent/highway-env.git 2> /dev/null
sys.path.insert(0, '/content/highway-env/scripts/')
#from utils import record_videos, show_videos

# %%
#%load_ext tensorboard.notebook
# %tensorboard --logdir "highway_dqn"
# Out:
# Reusing TensorBoard on port 6006 (pid 10822), started 11:27:06 ago. (Use '!kill 10822' to kill it.)
#       <iframe id="tensorboard-frame-92d1532755448f32" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-92d1532755448f32");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Highway Environment

# %%
model = DQN('MlpPolicy', 'mo-highway-v0', #highway_env/envs/highway_env.py 
                policy_kwargs=dict(net_arch=[256, 256]),
                learning_rate=5e-4,
                buffer_size=15000,
                learning_starts=200,
                batch_size=32,
                gamma=0.8,
                train_freq=1,
                gradient_steps=1,
                target_update_interval=50,
                exploration_fraction=0.7,
                verbose=1,
                tensorboard_log="highway_dqn/")
model.learn(int(2e4))

env = gym.make("mo-highway-v0")
info_all = []
for episode in trange(3, desc="Test episodes"):
    obs, done = env.reset(), False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(int(action))
        info_all.append(info)
        
env.close()
# Out:
# Using cpu device
# Creating environment from the given name 'mo-highway-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4        |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 62       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4        |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 112      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4        |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 149      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4        |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 240      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0193   |
# |    n_updates        | 39       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4        |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 297      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0911   |
# |    n_updates        | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4        |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 382      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00349  |
# |    n_updates        | 181      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4        |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 447      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.126    |
# |    n_updates        | 246      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.3     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4        |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 491      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0969   |
# |    n_updates        | 290      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.4     |
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4        |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 553      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.303    |
# |    n_updates        | 352      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4        |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 604      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0266   |
# |    n_updates        | 403      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4        |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 646      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.314    |
# |    n_updates        | 445      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.1     |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4        |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 727      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0141   |
# |    n_updates        | 526      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.5     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4        |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 806      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00663  |
# |    n_updates        | 605      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4        |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 840      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.231    |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15       |
# |    ep_rew_mean      | 11.9     |
# |    exploration_rate | 0.939    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4        |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 900      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.233    |
# |    n_updates        | 699      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.937    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4        |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 931      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.33     |
# |    n_updates        | 730      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4        |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 995      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.223    |
# |    n_updates        | 794      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4        |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 1037     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.131    |
# |    n_updates        | 836      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4        |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 1135     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 934      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.9     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4        |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 1189     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.242    |
# |    n_updates        | 988      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4        |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 1237     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00659  |
# |    n_updates        | 1036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.7     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4        |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 1294     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00991  |
# |    n_updates        | 1093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.6     |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4        |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 1345     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.384    |
# |    n_updates        | 1144     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4        |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 1382     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.473    |
# |    n_updates        | 1181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 4        |
# |    time_elapsed     | 289      |
# |    total_timesteps  | 1435     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.103    |
# |    n_updates        | 1234     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4        |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 1476     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.456    |
# |    n_updates        | 1275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4        |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 1527     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.581    |
# |    n_updates        | 1326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.3     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4        |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 1579     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.264    |
# |    n_updates        | 1378     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.2     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 4        |
# |    time_elapsed     | 334      |
# |    total_timesteps  | 1661     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0238   |
# |    n_updates        | 1460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.1     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 4        |
# |    time_elapsed     | 344      |
# |    total_timesteps  | 1710     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.225    |
# |    n_updates        | 1509     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.8     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 4        |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 1758     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.71     |
# |    n_updates        | 1557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 4        |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 1809     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.267    |
# |    n_updates        | 1608     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 4        |
# |    time_elapsed     | 374      |
# |    total_timesteps  | 1861     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.255    |
# |    n_updates        | 1660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 4        |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 1907     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.377    |
# |    n_updates        | 1706     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 4        |
# |    time_elapsed     | 398      |
# |    total_timesteps  | 1977     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.58     |
# |    n_updates        | 1776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14       |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 4        |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 2044     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.484    |
# |    n_updates        | 1843     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.7     |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 4        |
# |    time_elapsed     | 422      |
# |    total_timesteps  | 2099     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.136    |
# |    n_updates        | 1898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.3     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 4        |
# |    time_elapsed     | 429      |
# |    total_timesteps  | 2132     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.232    |
# |    n_updates        | 1931     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.2     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 4        |
# |    time_elapsed     | 436      |
# |    total_timesteps  | 2164     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.14     |
# |    n_updates        | 1963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 4        |
# |    time_elapsed     | 444      |
# |    total_timesteps  | 2205     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.126    |
# |    n_updates        | 2004     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 4        |
# |    time_elapsed     | 452      |
# |    total_timesteps  | 2242     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0388   |
# |    n_updates        | 2041     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 4        |
# |    time_elapsed     | 462      |
# |    total_timesteps  | 2294     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 2093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 4        |
# |    time_elapsed     | 469      |
# |    total_timesteps  | 2327     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.229    |
# |    n_updates        | 2126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 4        |
# |    time_elapsed     | 474      |
# |    total_timesteps  | 2351     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.228    |
# |    n_updates        | 2150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 4        |
# |    time_elapsed     | 486      |
# |    total_timesteps  | 2410     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.671    |
# |    n_updates        | 2209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.71     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 4        |
# |    time_elapsed     | 493      |
# |    total_timesteps  | 2447     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.145    |
# |    n_updates        | 2246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 9.49     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 4        |
# |    time_elapsed     | 500      |
# |    total_timesteps  | 2478     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.215    |
# |    n_updates        | 2277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 9.38     |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 4        |
# |    time_elapsed     | 508      |
# |    total_timesteps  | 2518     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0382   |
# |    n_updates        | 2317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 9.54     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 4        |
# |    time_elapsed     | 519      |
# |    total_timesteps  | 2572     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.437    |
# |    n_updates        | 2371     |
# ----------------------------------

# %% [markdown]
# ### Merge Environment

# %%
#%load_ext tensorboard.notebook
# %tensorboard --logdir "merge_dqn"
# Out:
# Reusing TensorBoard on port 6007 (pid 11453), started 0:10:50 ago. (Use '!kill 11453' to kill it.)
#       <iframe id="tensorboard-frame-693caa1685c93c8b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-693caa1685c93c8b");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model = DQN('MlpPolicy', 'merge-v0',
                policy_kwargs=dict(net_arch=[256, 256]),
                learning_rate=5e-4,
                buffer_size=15000,
                learning_starts=200,
                batch_size=32,
                gamma=0.8,
                train_freq=1,
                gradient_steps=1,
                target_update_interval=50,
                exploration_fraction=0.7,
                verbose=1, 
                tensorboard_log="merge_dqn/")
model.learn(int(2e4))
model.save('merge_dqn_exp/model')

env = gym.make("merge-v0")
# Out:
# Using cpu device
# Creating environment from the given name 'merge-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to merge_dqn/DQN_8
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 78       |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 50       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 79       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 79       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 152      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 79       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 77       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 257      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.161    |
# |    n_updates        | 56       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 76       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 309      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0712   |
# |    n_updates        | 108      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 75       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 356      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.128    |
# |    n_updates        | 155      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 75       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 400      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 199      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.5     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 75       |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 451      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.175    |
# |    n_updates        | 250      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 74       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 508      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0111   |
# |    n_updates        | 307      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 74       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 555      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.22     |
# |    n_updates        | 354      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 74       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 607      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0532   |
# |    n_updates        | 406      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 73       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 663      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.185    |
# |    n_updates        | 462      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 73       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 716      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.162    |
# |    n_updates        | 515      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.949    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 73       |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 757      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.217    |
# |    n_updates        | 556      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 73       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 807      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.17     |
# |    n_updates        | 606      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 73       |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 860      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.065    |
# |    n_updates        | 659      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 12.5     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 72       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 907      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.258    |
# |    n_updates        | 706      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.7     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 72       |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 964      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.167    |
# |    n_updates        | 763      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 72       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 1020     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.286    |
# |    n_updates        | 819      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 72       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 1074     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.116    |
# |    n_updates        | 873      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 72       |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 1131     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0955   |
# |    n_updates        | 930      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 72       |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 1180     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 979      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 72       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1237     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.18     |
# |    n_updates        | 1036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 72       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1288     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 1087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 72       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 1341     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0769   |
# |    n_updates        | 1140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 72       |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1393     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0849   |
# |    n_updates        | 1192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 72       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1447     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0931   |
# |    n_updates        | 1246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 71       |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 1491     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.427    |
# |    n_updates        | 1290     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 71       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1546     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0164   |
# |    n_updates        | 1345     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 71       |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 1593     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.125    |
# |    n_updates        | 1392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 71       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1650     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.267    |
# |    n_updates        | 1449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 71       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 1703     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 1502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 71       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 1762     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0308   |
# |    n_updates        | 1561     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 71       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1814     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.233    |
# |    n_updates        | 1613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 71       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1855     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.159    |
# |    n_updates        | 1654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 71       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1896     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0954   |
# |    n_updates        | 1695     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 71       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1947     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.207    |
# |    n_updates        | 1746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 71       |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 1994     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.127    |
# |    n_updates        | 1793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 71       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 2042     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.315    |
# |    n_updates        | 1841     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 71       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 2095     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.249    |
# |    n_updates        | 1894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 71       |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 2145     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0878   |
# |    n_updates        | 1944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 71       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 2204     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.107    |
# |    n_updates        | 2003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 71       |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 2261     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 2060     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 71       |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 2317     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0729   |
# |    n_updates        | 2116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 71       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 2373     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 2172     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 71       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 2424     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.173    |
# |    n_updates        | 2223     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 71       |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 2477     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0612   |
# |    n_updates        | 2276     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 71       |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 2530     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.119    |
# |    n_updates        | 2329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 71       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2584     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.101    |
# |    n_updates        | 2383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.821    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 71       |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 2635     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.169    |
# |    n_updates        | 2434     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 71       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 2682     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.13     |
# |    n_updates        | 2481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 71       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 2740     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.144    |
# |    n_updates        | 2539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 71       |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 2789     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.143    |
# |    n_updates        | 2588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 71       |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 2845     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.219    |
# |    n_updates        | 2644     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 71       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2889     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 2688     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 71       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 2945     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0183   |
# |    n_updates        | 2744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 71       |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 2993     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.123    |
# |    n_updates        | 2792     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 71       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 3039     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0858   |
# |    n_updates        | 2838     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 71       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 3090     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.072    |
# |    n_updates        | 2889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 71       |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 3144     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.221    |
# |    n_updates        | 2943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.783    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 71       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 3204     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0972   |
# |    n_updates        | 3003     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 72       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 3247     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0426   |
# |    n_updates        | 3046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 72       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 3295     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0851   |
# |    n_updates        | 3094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.773    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 72       |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 3351     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.114    |
# |    n_updates        | 3150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.769    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 72       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 3406     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0347   |
# |    n_updates        | 3205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.765    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 72       |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 3456     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 3255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 72       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 3513     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0834   |
# |    n_updates        | 3312     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.758    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 72       |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 3569     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.121    |
# |    n_updates        | 3368     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 72       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 3624     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.141    |
# |    n_updates        | 3423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 72       |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 3671     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0628   |
# |    n_updates        | 3470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 72       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 3722     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.221    |
# |    n_updates        | 3521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.744    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 72       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 3774     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.326    |
# |    n_updates        | 3573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 72       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 3823     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0893   |
# |    n_updates        | 3622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 72       |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 3880     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0328   |
# |    n_updates        | 3679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.733    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 72       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 3931     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0569   |
# |    n_updates        | 3730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.73     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 72       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 3974     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.151    |
# |    n_updates        | 3773     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 72       |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 4022     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0541   |
# |    n_updates        | 3821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.723    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 72       |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 4082     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0413   |
# |    n_updates        | 3881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 72       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 4141     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.236    |
# |    n_updates        | 3940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 72       |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 4199     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.181    |
# |    n_updates        | 3998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.712    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 72       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 4237     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0748   |
# |    n_updates        | 4036     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 72       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 4295     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.051    |
# |    n_updates        | 4094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 72       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 4348     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.089    |
# |    n_updates        | 4147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.1     |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 72       |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 4395     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0191   |
# |    n_updates        | 4194     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 72       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 4438     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0253   |
# |    n_updates        | 4237     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 72       |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 4487     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.115    |
# |    n_updates        | 4286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.693    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 72       |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 4528     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0602   |
# |    n_updates        | 4327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 72       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 4583     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.1      |
# |    n_updates        | 4382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 72       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 4641     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0457   |
# |    n_updates        | 4440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 72       |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 4699     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 4498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 13       |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 72       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 4757     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0344   |
# |    n_updates        | 4556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    time_elapsed     | 245      |
# |    total_timesteps  | 18051    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0168   |
# |    n_updates        | 17850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 73       |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 18116    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00565  |
# |    n_updates        | 17915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 73       |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 18179    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.03     |
# |    n_updates        | 17978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 73       |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 18243    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0109   |
# |    n_updates        | 18042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 73       |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 18305    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0219   |
# |    n_updates        | 18104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 73       |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 18368    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.015    |
# |    n_updates        | 18167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1304     |
# |    fps              | 73       |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 18431    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0132   |
# |    n_updates        | 18230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1308     |
# |    fps              | 73       |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 18495    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0253   |
# |    n_updates        | 18294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1312     |
# |    fps              | 73       |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 18560    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0286   |
# |    n_updates        | 18359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.8     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1316     |
# |    fps              | 73       |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 18622    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0578   |
# |    n_updates        | 18421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.7     |
# |    ep_rew_mean      | 16       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 73       |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 18684    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00961  |
# |    n_updates        | 18483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1324     |
# |    fps              | 73       |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 18751    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0107   |
# |    n_updates        | 18550    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1328     |
# |    fps              | 73       |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 18815    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0126   |
# |    n_updates        | 18614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1332     |
# |    fps              | 73       |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 18882    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0166   |
# |    n_updates        | 18681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1336     |
# |    fps              | 73       |
# |    time_elapsed     | 257      |
# |    total_timesteps  | 18946    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00791  |
# |    n_updates        | 18745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 73       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 19009    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00286  |
# |    n_updates        | 18808    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1344     |
# |    fps              | 73       |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 19069    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0117   |
# |    n_updates        | 18868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1348     |
# |    fps              | 73       |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 19135    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00935  |
# |    n_updates        | 18934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1352     |
# |    fps              | 73       |
# |    time_elapsed     | 260      |
# |    total_timesteps  | 19200    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0114   |
# |    n_updates        | 18999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1356     |
# |    fps              | 73       |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 19268    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0256   |
# |    n_updates        | 19067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 73       |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 19332    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0728   |
# |    n_updates        | 19131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 73       |
# |    time_elapsed     | 263      |
# |    total_timesteps  | 19398    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.133    |
# |    n_updates        | 19197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 73       |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 19462    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0128   |
# |    n_updates        | 19261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 73       |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 19526    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0297   |
# |    n_updates        | 19325    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 73       |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 19579    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00814  |
# |    n_updates        | 19378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 73       |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 19646    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0337   |
# |    n_updates        | 19445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 15.9     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 73       |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 19711    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0867   |
# |    n_updates        | 19510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 73       |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 19777    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0224   |
# |    n_updates        | 19576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16       |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 73       |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 19843    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0161   |
# |    n_updates        | 19642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 73       |
# |    time_elapsed     | 270      |
# |    total_timesteps  | 19910    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0953   |
# |    n_updates        | 19709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 16.1     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 73       |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 19977    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0166   |
# |    n_updates        | 19776    |
# ----------------------------------

# %%
info_all = []
for episode in trange(1000, desc="Test episodes"):
    obs, done = env.reset(), False
    while not done:
        
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(int(action))
        info_all.append(info)
        
env.close()

import numpy as np
crash_info = [i['crashed'] for i in info_all]
np.sum(crash_info) / len(crash_info)
# Out:
# Test episodes:   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       4     while not done:
#       6         action, _ = model.predict(obs, deterministic=True)
# ----> 7         obs, reward, done, info = env.step(int(action))
#       8         info_all.append(info)
#      10 env.close()
#
# File ~/miniconda3/lib/python3.9/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       9 def step(self, action):
#      10     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11     observation, reward, done, info = self.env.step(action)
#      12     return observation, reward, done, info
#
# File ~/Desktop/mo2/highway_env/envs/common/abstract.py:216, in AbstractEnv.step(self, action)
#     213     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     215 self.time += 1 / self.config["policy_frequency"]
# --> 216 self._simulate(action)
#     218 obs = self.observation_type.observe()
#     219 reward = self._reward(action)
#
# File ~/Desktop/mo2/highway_env/envs/common/abstract.py:236, in AbstractEnv._simulate(self, action)
#     233     self.action_type.act(action)
#     235 self.road.act()
# --> 236 self.road.step(1 / self.config["simulation_frequency"])
#     237 self.steps += 1
#     239 # Automatically render intermediate simulation steps if a viewer has been launched
#     240 # Ignored if the rendering is done offscreen
#
# File ~/Desktop/mo2/highway_env/road/road.py:333, in Road.step(self, dt)
#     327 """
#     328 Step the dynamics of each entity on the road.
#     329
#     330 :param dt: timestep [s]
#     331 """
#     332 for vehicle in self.vehicles:
# --> 333     vehicle.step(dt)
#     334 for i, vehicle in enumerate(self.vehicles):
#     335     for other in self.vehicles[i+1:]:
#
# File ~/Desktop/mo2/highway_env/vehicle/kinematics.py:131, in Vehicle.step(self, dt)
#     129 self.heading += self.speed * np.sin(beta) / (self.LENGTH / 2) * dt
#     130 self.speed += self.action['acceleration'] * dt
# --> 131 self.on_state_update()
#
# File ~/Desktop/mo2/highway_env/vehicle/kinematics.py:146, in Vehicle.on_state_update(self)
#     144 def on_state_update(self) -> None:
#     145     if self.road:
# --> 146         self.lane_index = self.road.network.get_closest_lane_index(self.position, self.heading)
#     147         self.lane = self.road.network.get_lane(self.lane_index)
#     148         if self.road.record_history:
#
# File ~/Desktop/mo2/highway_env/road/road.py:61, in RoadNetwork.get_closest_lane_index(self, position, heading)
#      59     for _to, lanes in to_dict.items():
#      60         for _id, l in enumerate(lanes):
# ---> 61             distances.append(l.distance_with_heading(position, heading))
#      62             indexes.append((_from, _to, _id))
#      63 return indexes[int(np.argmin(distances))]
#
# File ~/Desktop/mo2/highway_env/road/lane.py:125, in AbstractLane.distance_with_heading(self, position, heading, heading_weight)
#     123 if heading is None:
#     124     return self.distance(position)
# --> 125 s, r = self.local_coordinates(position)
#     126 angle = np.abs(self.local_angle(heading, s))
#     127 return abs(r) + max(s - self.length, 0) + max(0 - s, 0) + heading_weight*angle
#
# File ~/Desktop/mo2/highway_env/road/lane.py:190, in StraightLane.local_coordinates(self, position)
#     188 delta = position - self.start
#     189 longitudinal = np.dot(delta, self.direction)
# --> 190 lateral = np.dot(delta, self.direction_lateral)
#     191 return float(longitudinal), float(lateral)
#
# KeyboardInterrupt:

# %%
info_all
# Out:
# [{'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  {'speed': 20.00499268423365, 'crashed': False, 'action': 4},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 1},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 30.0, 'crashed': False, 'action': 2},
#  {'speed': 25.8544411731307, 'crashed': False, 'action': 4},
#  {'speed': 21.000455116798893, 'crashed': False, 'action': 4},
#  {'speed': 20.170966008732453, 'crashed': False, 'action': 4},
#  {'speed': 20.029216079413366, 'crashed': False, 'action': 4},
#  ...]

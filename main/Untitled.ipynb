# %%
# Install environment and agent
# Environment
import gym
import highway_env

# Agent
from stable_baselines3 import DQN

# Visualization utils
# %load_ext tensorboard
import sys
from tqdm.notebook import trange
#!pip install tensorboardx gym pyvirtualdisplay
#!apt-get install -y xvfb python-opengl ffmpeg
#!git clone https://github.com/eleurent/highway-env.git 2> /dev/null
sys.path.insert(0, '/content/highway-env/scripts/')
#from utils import record_videos, show_videos

# %%
#%load_ext tensorboard.notebook
# %tensorboard --logdir "highway_dqn"
# Out:
#       <iframe id="tensorboard-frame-3e4597cb1af7fc19" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3e4597cb1af7fc19");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### Highway Environment

# %%
model = DQN('MlpPolicy', 'mo-highway-v0', #highway_env/envs/highway_env.py 
                policy_kwargs=dict(net_arch=[256, 256]),
                learning_rate=5e-4,
                buffer_size=15000,
                learning_starts=200,
                batch_size=32,
                gamma=0.8,
                train_freq=1,
                gradient_steps=1,
                target_update_interval=50,
                exploration_fraction=0.7,
                verbose=1,
                tensorboard_log="highway_dqn/")
model.learn(int(2e4))
model.save('highway_dqn_exp/model')

env = gym.make("mo-highway-v0")
info_all = []
for episode in trange(3, desc="Test episodes"):
    obs, done = env.reset(), False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(int(action))
        info_all.append(info)
        
env.close()
# Out:
# Using cpu device
# Creating environment from the given name 'mo-highway-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_4
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 7.25     |
# |    ep_rew_mean      | 6.33     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4        |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5        |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 84       |
# ...

# %%
info_all = []
for episode in trange(1000, desc="Test episodes"):
    obs, done = env.reset(), False
    while not done:
        
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(int(action))
        info_all.append(info)
        
env.close()

import numpy as np
crash_info = [i['collision'] for i in info_all]
np.sum(crash_info) / len(crash_info)
# Out:
# Test episodes:   0%|          | 0/1000 [00:00<?, ?it/s]
# 0.004383909123493893

# %%
import numpy as np
crash_info = [i['collision'] for i in info_all]
np.sum(crash_info) / len(crash_info)
# Out:
# 0.027655586581494092

# %% [markdown]
# ### Merge Environment

# %%
#%load_ext tensorboard.notebook
# %tensorboard --logdir "merge_dqn"

# %%
model = DQN('MlpPolicy', 'merge-v0',
                policy_kwargs=dict(net_arch=[256, 256]),
                learning_rate=5e-4,
                buffer_size=15000,
                learning_starts=200,
                batch_size=32,
                gamma=0.8,
                train_freq=1,
                gradient_steps=1,
                target_update_interval=50,
                exploration_fraction=0.7,
                verbose=1, 
                tensorboard_log="merge_dqn/")
model.learn(int(2e4))

env = gym.make("merge-v0")

info_all = []
for episode in trange(3, desc="Test episodes"):
    obs, done = env.reset(), False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(int(action))
        info_all.append(info)
        
env.close()
show_videos()
# Out:
# Using cpu device
# Creating environment from the given name 'merge-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 32       |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 32       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 104      |
# ----------------------------------
# ...
